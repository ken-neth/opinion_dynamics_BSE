# %% [markdown]
# # data analysis

# %%
import csv
from matplotlib.pyplot import *

# %%
transactions = []

with open('transactions.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    for row in readCSV:
        transactions.append([float(row[0]), float(row[1])])

# %%
time = np.array(transactions)[:,0]
price = np.array(transactions)[:,1]


# nums = np.arange(0, 600, 100)


figure(1, figsize=(10,10))
xlabel('Time')
ylabel('Price')
title("Transactions")
p1 = scatter(time, price, marker='x')
ylim(ymin=0, ymax=200)
xlim(xmin=0, xmax=180)
show()

# %%
time = []
avg_balance = []

with open('avg_balance.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    for row in readCSV:
        time.append(float(row[1]))
        avg_balance.append(float(row[5]))

figure(2, figsize=(10,10))
xlabel('Time')
ylabel('avg_balance')
title("avg_balance")
p2 = plot(time, avg_balance)
ylim(ymin=0, ymax=200)
xlim(xmin=0, xmax=180)
show()

# %%
trader = 1
traders = [trader]
traders.append(2)
traders

# def to_float(arr):
#     ret = []
#     for a in arr:
#         ret.append(float(a))
#     return ret
# Out:
# [1, 2]

# %%
step = []
step_n = 0
opinions = []

with open('BCopinions.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    for row in readCSV:
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append(step_n)
        step_n += 1
        
sub_op = []
sub_step = []
for i in range(len(opinions)):
    if step[i] == 0:
        sub_op.append(opinions[i])
        sub_step.append(0)

figure(3, figsize=(10,10))
xlabel('Step')
ylabel('Opinion')
title("Relative Disagreement mu = 0.2 lambda = 0.1")
p3 = scatter(step, opinions, marker='x')
show()

# %%
arr = [1,3,4,5,6]
arr[2:4] * 2
# Out:
# [4, 5, 4, 5]

# %%
random.random()
# Out:
# 0.20384157150906235

# %%
import random
min((random.uniform(0.2, 2.0) + random.uniform(0, 1)), 2)
# Out:
# 1.3247502829717708

# %%
random.uniform(-1, 1)
# Out:
# -0.93139220453172
