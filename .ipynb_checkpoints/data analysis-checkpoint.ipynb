# %% [markdown]
# # data analysis

# %%
import csv
from matplotlib.pyplot import *
import matplotlib.colors
import numpy

# %%
transactions = []

with open('transactions.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    for row in readCSV:
        transactions.append([float(row[0]), float(row[1])])

time = np.array(transactions)[:,0]
price = np.array(transactions)[:,1]


# nums = np.arange(0, 600, 100)


figure(1, figsize=(10,10))
xlabel('Time')
ylabel('Price')
title("Transactions")
p1 = scatter(time, price, marker='x', color='green')
p1 = plot(time, price, 'red')
ax = axes()
ax.set_facecolor('midnightblue')
ylim(ymin=50, ymax=200)
xlim(xmin=0, xmax=180)
show()
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
time = []
avg_balance = []

with open('avg_balance.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    for row in readCSV:
        time.append(float(row[1]))
        avg_balance.append(float(row[5]))

figure(2, figsize=(10,10))
xlabel('Time')
ylabel('avg_balance')
title("avg_balance")
p2 = plot(time, avg_balance)
ylim(ymin=0, ymax=200)
xlim(xmin=0, xmax=180)
show()

# %%
step = []
step_n = 0
opinions = []
cs = []

model_name = 'RA'

with open(model_name+'opinions.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    for row in readCSV:
        for opinion in row[4:]:
            if opinion != ' ':
                opinions.append(float(opinion))
                step.append(step_n)
        step_n += 1
        
# sub_op = []
# sub_step = []
# for i in range(len(opinions)):
#     if step[i] == 0:
#         sub_op.append(opinions[i]*100)
#         sub_step.append(0)

cmap = matplotlib.colors.ListedColormap(["red","orange","gold","gold", "gold","gold", "orange","red"])

figure(3, figsize=(10,10))
xlabel('Step', fontsize=30)
ylabel('Opinion', fontsize=30)
title(model_name +" mu=0.2", fontsize=30)
p3 = scatter(step, opinions, c=opinions, cmap=cmap)
show()

# %%
with open('ymetric.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    for row in readCSV:
        print(row)
# Out:
# ['0.200000 0.025000 0.105099 0.001041 0.028512 0.038614 ']
# ['0.200000 0.050000 0.058264 0.001189 0.018312 0.020535 ']
# ['0.200000 0.075000 0.021403 0.004756 0.010702 0.005874 ']
# ['0.200000 0.100000 0.198903 0.002743 0.085597 0.072173 ']
# ['0.200000 0.125000 0.449931 0.002743 0.161866 0.187175 ']
# ['0.200000 0.150000 0.034294 0.005487 0.012894 0.010994 ']
# ['0.200000 0.175000 0.558400 0.006400 0.140800 0.211747 ']
# ['0.200000 0.200000 1.787200 0.136000 1.062720 0.556133 ']
# ['0.200000 0.225000 0.904000 0.006400 0.228800 0.342001 ']
# ['0.200000 0.250000 1.181474 0.001890 0.621928 0.509957 ']
# ['0.200000 0.275000 0.756144 0.319471 0.518715 0.148176 ']
# ['0.200000 0.300000 1.417234 0.192744 0.740590 0.452103 ']
# ['0.300000 0.025000 0.052029 0.000000 0.013111 0.019761 ']
# ['0.300000 0.050000 0.200951 0.002378 0.076813 0.073782 ']
# ['0.300000 0.075000 0.034483 0.000000 0.013793 0.015496 ']
# ['0.300000 0.100000 0.604938 0.000000 0.177229 0.238417 ']
# ['0.300000 0.125000 1.235940 0.001372 0.412894 0.451134 ']
# ['0.300000 0.150000 0.231824 0.006859 0.137449 0.086367 ']
# ['0.300000 0.175000 0.385600 0.006400 0.156800 0.150376 ']
# ['0.300000 0.200000 0.084800 0.006400 0.031680 0.027628 ']
# ['0.300000 0.225000 2.336000 0.006400 0.784000 0.976544 ']
# ['0.300000 0.250000 1.512287 0.115312 0.579206 0.504582 ']
# ['0.300000 0.275000 0.758034 0.200378 0.463138 0.182910 ']
# ['0.300000 0.300000 1.326531 0.131519 0.707937 0.469512 ']
# ['0.400000 0.025000 0.126951 0.000000 0.030385 0.048605 ']
# ['0.400000 0.050000 0.747919 0.001189 0.194530 0.286846 ']
# ['0.400000 0.075000 0.148633 0.000000 0.031153 0.058761 ']
# ['0.400000 0.100000 0.027435 0.000000 0.011523 0.009206 ']
# ['0.400000 0.125000 0.264746 0.000000 0.065295 0.101281 ']
# ['0.400000 0.150000 0.274348 0.010974 0.125652 0.109851 ']
# ['0.400000 0.175000 1.395200 0.014400 0.434240 0.548800 ']
# ['0.400000 0.200000 1.115200 0.006400 0.371200 0.415220 ']
# ['0.400000 0.225000 0.769600 0.115200 0.460480 0.254325 ']
# ['0.400000 0.250000 2.875236 0.047259 1.441588 0.901933 ']
# ['0.400000 0.275000 2.499055 0.001890 0.643478 0.933839 ']
# ['0.400000 0.300000 1.818594 0.183673 1.064399 0.598613 ']
# ['0.500000 0.025000 0.884495 0.000000 0.200208 0.344342 ']
# ['0.500000 0.050000 0.076100 0.000000 0.034245 0.028876 ']
# ['0.500000 0.075000 0.095125 0.000000 0.019263 0.037934 ']
# ['0.500000 0.100000 0.054870 0.000000 0.018381 0.019795 ']
# ['0.500000 0.125000 0.203018 0.001372 0.050754 0.077077 ']
# ['0.500000 0.150000 2.076818 0.027435 0.707270 0.766919 ']
# ['0.500000 0.175000 0.360000 0.001600 0.098560 0.135158 ']
# ['0.500000 0.200000 1.254400 0.080000 0.596800 0.497134 ']
# ['0.500000 0.225000 0.886400 0.129600 0.347520 0.274172 ']
# ['0.500000 0.250000 1.589792 0.000000 0.371267 0.614597 ']
# ['0.500000 0.275000 0.689981 0.160681 0.389036 0.189758 ']
# ['0.500000 0.300000 1.997732 0.367347 1.092063 0.594095 ']
# ['0.600000 0.025000 0.054110 0.000000 0.016441 0.019726 ']
# ['0.600000 0.050000 0.030916 0.001189 0.011653 0.011636 ']
# ['0.600000 0.075000 0.171225 0.000000 0.055886 0.061317 ']
# ['0.600000 0.100000 1.318244 0.001372 0.322908 0.504657 ']
# ['0.600000 0.125000 0.142661 0.001372 0.061454 0.054549 ']
# ['0.600000 0.150000 1.319616 0.021948 0.521811 0.499956 ']
# ['0.600000 0.175000 2.204800 0.006400 0.723200 0.793133 ']
# ['0.600000 0.200000 1.440000 0.025600 0.328640 0.556238 ']
# ['0.600000 0.225000 0.464000 0.000000 0.108800 0.178085 ']
# ['0.600000 0.250000 0.372401 0.000000 0.211720 0.143339 ']
# ['0.600000 0.275000 1.852552 0.001890 0.769376 0.633674 ']
# ['0.600000 0.300000 1.199546 0.145125 0.699773 0.455627 ']
# ['0.700000 0.025000 0.126951 0.000000 0.027263 0.049889 ']
# ['0.700000 0.050000 0.190250 0.000000 0.042568 0.073984 ']
# ['0.700000 0.075000 0.019025 0.000000 0.007610 0.006452 ']
# ['0.700000 0.100000 0.197531 0.010974 0.066392 0.068557 ']
# ['0.700000 0.125000 0.079561 0.001372 0.037037 0.026978 ']
# ['0.700000 0.150000 1.268861 0.001372 0.313580 0.489403 ']
# ['0.700000 0.175000 0.366400 0.003200 0.174400 0.125650 ']
# ['0.700000 0.200000 1.465600 0.016000 0.497600 0.518554 ']
# ['0.700000 0.225000 1.753600 0.046400 0.689920 0.638117 ']
# ['0.700000 0.250000 2.058601 0.037807 0.696408 0.729771 ']
# ['0.700000 0.275000 0.257089 0.018904 0.075992 0.091423 ']
# ['0.700000 0.300000 1.725624 0.000000 0.781859 0.697824 ']
# ['0.800000 0.025000 0.020812 0.000000 0.004787 0.008023 ']
# ['0.800000 0.050000 0.137931 0.000000 0.032818 0.052860 ']
# ['0.800000 0.075000 1.541023 0.000000 0.407372 0.595967 ']
# ['0.800000 0.100000 0.165981 0.089163 0.129492 0.026650 ']
# ['0.800000 0.125000 0.857339 0.001372 0.259259 0.319773 ']
# ['0.800000 0.150000 0.857339 0.012346 0.210974 0.326544 ']
# ['0.800000 0.175000 1.740800 0.014400 0.459520 0.662090 ']
# ['0.800000 0.200000 1.088000 0.000000 0.300480 0.406159 ']
# ['0.800000 0.225000 0.230400 0.006400 0.120320 0.085730 ']
# ['0.800000 0.250000 2.366730 0.003781 0.536106 0.917832 ']
# ['0.800000 0.275000 1.398866 0.032136 0.448015 0.495532 ']
# ['0.800000 0.300000 1.201814 0.002268 0.420862 0.428260 ']
# ['0.900000 0.025000 0.203954 0.002081 0.067430 0.077584 ']
# ['0.900000 0.050000 0.385256 0.020214 0.139596 0.129961 ']
# ['0.900000 0.075000 0.434007 0.000000 0.094174 0.170099 ']
# ['0.900000 0.100000 0.149520 0.001372 0.053498 0.059975 ']
# ['0.900000 0.125000 0.111111 0.000000 0.057339 0.040166 ']
# ['0.900000 0.150000 1.318244 0.006859 0.359122 0.491522 ']
# ['0.900000 0.175000 1.448000 0.006400 0.422720 0.542874 ']
# ['0.900000 0.200000 1.308800 0.040000 0.456640 0.490409 ']
# ['0.900000 0.225000 2.259200 0.000000 0.513600 0.875181 ']
# ['0.900000 0.250000 1.030246 0.190926 0.559924 0.323898 ']
# ['0.900000 0.275000 2.504726 0.047259 0.616257 0.946285 ']
# ['0.900000 0.300000 2.097506 0.102041 0.676644 0.727910 ']
# ['1.000000 0.025000 0.009365 0.000000 0.003122 0.003420 ']
# ['1.000000 0.050000 2.098692 0.000000 0.424970 0.836893 ']
# ['1.000000 0.075000 0.309156 0.002378 0.079191 0.115528 ']
# ['1.000000 0.100000 0.244170 0.005487 0.097942 0.098352 ']
# ['1.000000 0.125000 0.056241 0.005487 0.030178 0.017843 ']
# ['1.000000 0.150000 1.075446 0.000000 0.242250 0.419179 ']
# ['1.000000 0.175000 0.518400 0.078400 0.255360 0.164744 ']
# ['1.000000 0.200000 0.270400 0.003200 0.130240 0.109108 ']
# ['1.000000 0.225000 0.532800 0.059200 0.258560 0.221147 ']
# ['1.000000 0.250000 1.816635 0.000000 0.507750 0.692167 ']
# ['1.000000 0.275000 1.922495 0.054820 0.611342 0.715307 ']
# ['1.000000 0.300000 2.947846 0.657596 1.851247 0.886184 ']
# ['1.100000 0.025000 0.026015 0.001041 0.009990 0.011083 ']
# ['1.100000 0.050000 0.034483 0.001189 0.014269 0.014698 ']
# ['1.100000 0.075000 0.029727 0.000000 0.012366 0.010939 ']
# ['1.100000 0.100000 0.171468 0.000000 0.051303 0.063139 ']
# ['1.100000 0.125000 2.903978 0.027435 0.654321 1.128595 ']
# ['1.100000 0.150000 0.495199 0.000000 0.108642 0.193637 ']
# ['1.100000 0.175000 0.936000 0.014400 0.213760 0.361279 ']
# ['1.100000 0.200000 2.051200 0.027200 0.502400 0.782246 ']
# ['1.100000 0.225000 0.411200 0.001600 0.152960 0.148352 ']
# ['1.100000 0.250000 0.880907 0.017013 0.282042 0.313148 ']
# ['1.100000 0.275000 1.156900 0.077505 0.488469 0.428126 ']
# ['1.100000 0.300000 2.308390 0.011338 0.838095 0.832088 ']
# ['1.200000 0.025000 0.085328 0.001041 0.025390 0.031291 ']
# ['1.200000 0.050000 0.267539 0.004756 0.078716 0.096452 ']
# ['1.200000 0.075000 0.686088 0.000000 0.186445 0.257498 ']
# ['1.200000 0.100000 0.089163 0.001372 0.032922 0.033047 ']
# ['1.200000 0.125000 0.507545 0.001372 0.131962 0.190257 ']
# ['1.200000 0.150000 0.054870 0.000000 0.015089 0.020457 ']
# ['1.200000 0.175000 0.780800 0.008000 0.293760 0.258865 ']
# ['1.200000 0.200000 0.144000 0.014400 0.050560 0.047416 ']
# ['1.200000 0.225000 2.233600 0.020800 0.538560 0.855491 ']
# ['1.200000 0.250000 1.833648 0.017013 0.662004 0.701796 ']
# ['1.200000 0.275000 1.833648 0.001890 0.723629 0.807487 ']
# ['1.200000 0.300000 2.403628 0.040816 1.034921 0.851813 ']
# ['1.300000 0.025000 0.234131 0.004162 0.060978 0.087547 ']
# ['1.300000 0.050000 1.001189 0.005945 0.231629 0.387066 ']
# ['1.300000 0.075000 0.034483 0.000000 0.016171 0.013960 ']
# ['1.300000 0.100000 0.418381 0.000000 0.098217 0.160845 ']
# ['1.300000 0.125000 0.352538 0.001372 0.116598 0.128071 ']
# ['1.300000 0.150000 1.894376 0.010974 0.425789 0.736101 ']
# ['1.300000 0.175000 0.259200 0.003200 0.073920 0.093610 ']
# ['1.300000 0.200000 0.579200 0.000000 0.202560 0.238471 ']
# ['1.300000 0.225000 0.174400 0.001600 0.070400 0.056686 ']
# ['1.300000 0.250000 1.667297 0.094518 0.702457 0.687622 ']
# ['1.300000 0.275000 2.499055 0.018904 0.731569 0.944689 ']
# ['1.300000 0.300000 2.290249 0.183673 1.053515 0.960079 ']
# ['1.400000 0.025000 0.084287 0.000000 0.026431 0.031948 ']
# ['1.400000 0.050000 0.076100 0.004756 0.023306 0.027329 ']
# ['1.400000 0.075000 0.633769 0.010702 0.170511 0.233213 ']
# ['1.400000 0.100000 0.277092 0.049383 0.117970 0.085670 ']
# ['1.400000 0.125000 0.462277 0.001372 0.110562 0.177774 ']
# ['1.400000 0.150000 0.858711 0.013717 0.272977 0.309389 ']
# ['1.400000 0.175000 0.540800 0.001600 0.189120 0.221807 ']
# ['1.400000 0.200000 0.577600 0.001600 0.153920 0.219864 ']
# ['1.400000 0.225000 2.131200 0.001600 0.919040 0.908158 ']
# ['1.400000 0.250000 0.850662 0.032136 0.342911 0.313487 ']
# ['1.400000 0.275000 0.689981 0.000000 0.303970 0.245765 ']
# ['1.400000 0.300000 1.199546 0.065760 0.473923 0.457832 ']
# ['1.500000 0.025000 0.017690 0.001041 0.009157 0.007221 ']
# ['1.500000 0.050000 0.186683 0.000000 0.038050 0.074318 ']
# ['1.500000 0.075000 0.034483 0.002378 0.017836 0.013432 ']
# ['1.500000 0.100000 0.034294 0.000000 0.011523 0.012288 ']
# ['1.500000 0.125000 0.928669 0.002743 0.271879 0.338767 ']
# ['1.500000 0.150000 0.244170 0.000000 0.070508 0.094972 ']
# ['1.500000 0.175000 1.497600 0.028800 0.474560 0.529649 ']
# ['1.500000 0.200000 0.921600 0.020800 0.355520 0.329134 ']
# ['1.500000 0.225000 1.440000 0.014400 0.400960 0.541494 ']
# ['1.500000 0.250000 1.378072 0.075614 0.608318 0.515909 ']
# ['1.500000 0.275000 1.606805 0.000000 0.729679 0.644755 ']
# ['1.500000 0.300000 2.548753 0.326531 1.102948 0.859960 ']
# ['1.600000 0.025000 0.243496 0.000000 0.062227 0.094198 ']
# ['1.600000 0.050000 0.833532 0.001189 0.294174 0.305462 ']
# ['1.600000 0.075000 0.475624 0.001189 0.130321 0.181967 ']
# ['1.600000 0.100000 0.396433 0.001372 0.161866 0.139659 ']
# ['1.600000 0.125000 0.351166 0.013717 0.122085 0.122179 ']
# ['1.600000 0.150000 0.375857 0.000000 0.136077 0.146270 ']
# ['1.600000 0.175000 0.276800 0.065600 0.197440 0.076524 ']
# ['1.600000 0.200000 0.846400 0.000000 0.210240 0.325608 ']
# ['1.600000 0.225000 0.102400 0.012800 0.053760 0.029005 ']
# ['1.600000 0.250000 2.419660 0.000000 0.759924 0.863762 ']
# ['1.600000 0.275000 0.914934 0.001890 0.369754 0.337694 ']
# ['1.600000 0.300000 1.145125 0.310658 0.697506 0.326419 ']
# ['1.700000 0.025000 0.017690 0.000000 0.008533 0.006692 ']
# ['1.700000 0.050000 0.042806 0.005945 0.021879 0.013125 ']
# ['1.700000 0.075000 0.175981 0.000000 0.069917 0.065721 ']
# ['1.700000 0.100000 0.692730 0.001372 0.314403 0.289123 ']
# ['1.700000 0.125000 0.204390 0.000000 0.056790 0.076368 ']
# ['1.700000 0.150000 1.001372 0.012346 0.431001 0.441874 ']
# ['1.700000 0.175000 0.848000 0.014400 0.313280 0.297869 ']
# ['1.700000 0.200000 1.168000 0.000000 0.276160 0.447984 ']
# ['1.700000 0.225000 2.075200 0.014400 0.573760 0.777382 ']
# ['1.700000 0.250000 1.597353 0.009452 0.627977 0.525885 ']
# ['1.700000 0.275000 0.514178 0.007561 0.225709 0.168162 ']
# ['1.700000 0.300000 1.752834 0.081633 0.830385 0.680087 ']
# ['1.800000 0.025000 0.088450 0.000000 0.036420 0.032615 ']
# ['1.800000 0.050000 0.077289 0.000000 0.024257 0.030572 ']
# ['1.800000 0.075000 1.070155 0.143876 0.476576 0.345914 ']
# ['1.800000 0.100000 0.244170 0.000000 0.102881 0.098689 ']
# ['1.800000 0.125000 0.006859 0.000000 0.001920 0.002544 ']
# ['1.800000 0.150000 0.165981 0.001372 0.056241 0.063237 ']
# ['1.800000 0.175000 0.921600 0.003200 0.320320 0.352262 ']
# ['1.800000 0.200000 3.049600 0.025600 0.691840 1.180137 ']
# ['1.800000 0.225000 0.640000 0.115200 0.357760 0.203628 ']
# ['1.800000 0.250000 1.105860 0.018904 0.504726 0.359099 ']
# ['1.800000 0.275000 1.030246 0.069943 0.506994 0.331650 ']
# ['1.800000 0.300000 2.417234 0.056689 0.811338 0.853745 ']
# ['1.900000 0.025000 0.026015 0.000000 0.008741 0.009505 ']
# ['1.900000 0.050000 0.021403 0.000000 0.009750 0.007229 ']
# ['1.900000 0.075000 0.518430 0.000000 0.108205 0.205164 ']
# ['1.900000 0.100000 1.857339 0.000000 0.423320 0.718329 ']
# ['1.900000 0.125000 0.466392 0.006859 0.165158 0.162262 ']
# ['1.900000 0.150000 0.351166 0.001372 0.088615 0.132467 ']
# ['1.900000 0.175000 3.328000 0.014400 0.790400 1.273022 ']
# ['1.900000 0.200000 1.000000 0.001600 0.418240 0.368321 ']
# ['1.900000 0.225000 0.116800 0.025600 0.070080 0.037719 ']
# ['1.900000 0.250000 1.671078 0.001890 0.580340 0.583269 ']
# ['1.900000 0.275000 2.164461 0.017013 0.717958 0.826761 ']
# ['1.900000 0.300000 0.734694 0.000000 0.213605 0.270997 ']
# ['2.000000 0.025000 0.016649 0.000000 0.003954 0.006360 ']
# ['2.000000 0.050000 0.029727 0.000000 0.014269 0.011330 ']
# ['2.000000 0.075000 0.118906 0.000000 0.051130 0.050487 ']
# ['2.000000 0.100000 2.722908 0.034294 0.858711 1.050762 ']
# ['2.000000 0.125000 1.680384 0.000000 0.343759 0.668372 ']
# ['2.000000 0.150000 0.507545 0.005487 0.128669 0.191658 ']
# ['2.000000 0.175000 0.411200 0.008000 0.169600 0.164503 ']
# ['2.000000 0.200000 0.923200 0.001600 0.213440 0.356918 ']
# ['2.000000 0.225000 0.385600 0.032000 0.193600 0.135753 ']
# ['2.000000 0.250000 2.483932 0.007561 0.661248 0.923402 ']
# ['2.000000 0.275000 1.181474 0.189036 0.447259 0.380660 ']
# ['2.000000 0.300000 2.875283 0.011338 1.175964 1.153946 ']

# %%
random.randint(1,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7a5b329ab15c> in <module>()
# ----> 1 random.randint(1,1)
#
# NameError: name 'random' is not defined
