# %% [markdown]
# # y metrics

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
us = np.arange(0.2, 2.1, 0.1)
pes = np.arange(0.025, 0.31, 0.025)

usv, pesv = np.meshgrid(us, pes)

# %%
ys = np.array([])

with open('/Users/kennethlomas/Desktop/BristolStockExchange-master/csv_files/ymetric.csv') as csv_file:
    readCSV = csv.reader(csv_file, delimiter=',')
    temp = np.array([])
    for row in readCSV:
    
        row = str(row).split()
        
        if float(row[1]) < 0.3:
            temp = np.append(temp, float(row[4]))
        else:
            temp = np.append(temp, float(row[4]))
            
            if ys.size == 0:
                ys = np.append(ys, temp)
            else:
                ys = np.vstack((ys, temp))
            temp = np.array([])
            prev_pe = 0

# %%
us = np.arange(0.2, 2.1, 0.1)
pes = np.arange(0.025, 0.31, 0.025)

usv, pesv = np.meshgrid(us, pes)

fig, ax = plt.subplots(figsize=(20,20))
im = ax.imshow(np.transpose(ys))

ax.set_xticks(np.arange(len(us)))
ax.set_yticks(np.arange(len(pes)))

ax.set_xticklabels(us)
ax.set_yticklabels(pes)

plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

plt.xlabel('uncertainty, u',fontsize=30)
plt.ylabel('proportion of extremists in population, pe',fontsize=30)
# plt.ylim(ymin=0.025, ymax=0.3)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# this code will print numbers on the tiles
# for i in range(len(us)):
#     for j in range(len(pes)):
#         text = ax.text(i, j, ys[i, j],
#                        ha="center", va="center", color="w")

# ax.set_title()
cbar = fig.colorbar(im, shrink=0.5, aspect=5, orientation="horizontal", pad=0.1)
ticklabs = cbar.ax.get_xticklabels()
cbar.ax.set_xticklabels(ticklabs, fontsize=24)
fig.tight_layout()
plt.show()
